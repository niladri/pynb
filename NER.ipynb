# %%
import nltk

# %%
text = open("example.txt").read().decode("utf-8")

# %%
text
# Out:
# u'\n\n\n\n<!DOCTYPE html>\n<html lang="en" class=" emoji-size-boost is-u2f-enabled">\n  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# object: http://ogp.me/ns/object# article: http://ogp.me/ns/article# profile: http://ogp.me/ns/profile#">\n    <meta charset=\'utf-8\'>\n    \n\n    <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-c07e6f4b02b556d1d85052fb3853caf84c80e6b23dcdb1ae1b00f051da1115a2.css" integrity="sha256-wH5vSwK1VtHYUFL7OFPK+EyA5rI9zbGuGwDwUdoRFaI=" media="all" rel="stylesheet" />\n    <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-09e1c38d593bf8fc6e4c4f1b526d0184e27c433d64963942c1e8c361589f8125.css" integrity="sha256-CeHDjVk7+PxuTE8bUm0BhOJ8Qz1kljlCwejDYVifgSU=" media="all" rel="stylesheet" />\n    \n    \n    \n    \n\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta http-equiv="Content-Language" content="en">\n    <meta name="viewport" content="width=device-width">\n    \n    <title>Introduction-to-NLP/example.txt at master \xb7 bsacash/Introduction-to-NLP</title>\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n    <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n    <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png">\n    <link rel="apple-touch-icon" sizes="60x60" href="/apple-touch-icon-60x60.png">\n    <link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png">\n    <link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png">\n    <link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png">\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png">\n    <meta property="fb:app_id" content="1401488693436528">\n\n      <meta content="https://avatars2.githubusercontent.com/u/2559813?v=3&amp;s=400" name="twitter:image:src" /><meta content="@github" name="twitter:site" /><meta content="summary" name="twitter:card" /><meta content="bsacash/Introduction-to-NLP" name="twitter:title" /><meta content="Introduction-to-NLP - Lectures for Udemy - INLP" name="twitter:description" />\n      <meta content="https://avatars2.githubusercontent.com/u/2559813?v=3&amp;s=400" property="og:image" /><meta content="GitHub" property="og:site_name" /><meta content="object" property="og:type" /><meta content="bsacash/Introduction-to-NLP" property="og:title" /><meta content="https://github.com/bsacash/Introduction-to-NLP" property="og:url" /><meta content="Introduction-to-NLP - Lectures for Udemy - INLP" property="og:description" />\n      <meta name="browser-stats-url" content="https://api.github.com/_private/browser/stats">\n    <meta name="browser-errors-url" content="https://api.github.com/_private/browser/errors">\n    <link rel="assets" href="https://assets-cdn.github.com/">\n    <link rel="web-socket" href="wss://live.github.com/_sockets/VjI6MTQ4ODkxMDIxOmYwMDE5OGIyYWI1YTU4OGE1NzM5NGQxNjU0OTVkYjI4Mzc3MzY0ODkxMzM4YmY0ZWQ5YmVkYzJkYTc4OWJmYTQ=--6b2374bf6b204760c41c52e3d73ad5fc08447989">\n    <meta name="pjax-timeout" content="1000">\n    <link rel="sudo-modal" href="/sessions/sudo_modal">\n    <meta name="request-id" content="580D:4322:11E3716:1D1C6DC:58836992" data-pjax-transient>\n\n    <meta name="msapplication-TileImage" content="/windows-tile.png">\n    <meta name="msapplication-TileColor" content="#ffffff">\n    <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n    <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n<meta name="google-site-ver ...

# %%
text_tag = nltk.pos_tag(nltk.word_tokenize(text))

# %%
text_ch = nltk.ne_chunk(text_tag)

# %%
for chunk in text_ch:
    if hasattr(chunk, 'label'):
        print chunk.label(), " ".join(c[0] for c in chunk.leaves())
# Out:
# ORGANIZATION DOCTYPE
# ORGANIZATION GitHub
# ORGANIZATION GitHub
# PERSON Udemy
# ORGANIZATION INLP
# ORGANIZATION GitHub
# PERSON Udemy
# ORGANIZATION INLP
# PERSON Udemy
# ORGANIZATION INLP
# PERSON Skip
# PERSON Search GitHub
# PERSON Nav
# ORGANIZATION Pull
# PERSON Nav
# PERSON Issues
# ORGANIZATION Gist
# ORGANIZATION Create
# GPE New
# GPE Import
# GPE New
# GPE New
# GPE New
# PERSON Explore
# ORGANIZATION Integrations
# PERSON Help
# PERSON Settings
# GPE Watch
# PERSON Watch
# PERSON Watch
# PERSON Unwatch
# ORGANIZATION Unstar
# PERSON Unstar
# PERSON Code
# PERSON Issues
# PERSON Permalink
# GPE Switch
# GPE Switch
# ORGANIZATION Branches
# PERSON Tags
# ORGANIZATION BtnGroup
# PERSON Copy
# GPE Copy
# GPE Tagging
# PERSON Chunking
# ORGANIZATION BtnGroup
# PERSON Raw
# PERSON Blame
# ORGANIZATION GitHub
# ORGANIZATION LC1
# ORGANIZATION WWII
# ORGANIZATION WW2
# ORGANIZATION Second
# ORGANIZATION Axis
# ORGANIZATION Hiroshima
# GPE Nagasaki
# ORGANIZATION LC2
# ORGANIZATION LC3
# ORGANIZATION Empire
# GPE Japan
# GPE Asia
# ORGANIZATION Pacific
# ORGANIZATION Republic
# GPE China
# GPE Poland
# GPE Germany
# GPE Germany
# GPE France
# ORGANIZATION United Kingdom
# GPE Germany
# GPE Europe
# ORGANIZATION Axis
# GPE Italy
# GPE Japan
# GPE Germany
# GPE Soviet Union
# GPE European
# GPE Poland
# GPE Finland
# GPE Romania
# GPE Baltic
# ORGANIZATION United Kingdom
# GPE British
# ORGANIZATION European Axis
# GPE North Africa
# ORGANIZATION Horn
# GPE Africa
# GPE Britain
# GPE Blitz
# ORGANIZATION Atlantic
# ORGANIZATION European Axis
# GPE Soviet Union
# ORGANIZATION Axis
# GPE Japan
# GPE United States
# GPE European
# ORGANIZATION Pacific Ocean
# LOCATION Western
# ORGANIZATION LC4
# ORGANIZATION LC5
# ORGANIZATION Axis
# PERSON Japan
# GPE Midway
# GPE Hawaii
# GPE Germany
# GPE North Africa
# FACILITY Stalingrad
# GPE Soviet Union
# GPE German
# LOCATION Eastern Front
# GPE Italy
# GPE Italian
# GPE Allied
# ORGANIZATION Pacific
# ORGANIZATION Axis
# LOCATION Western
# GPE France
# GPE Soviet Union
# GPE Germany
# GPE Japanese
# GPE Asia
# GPE South
# GPE China
# GPE Burma
# GPE Japanese
# ORGANIZATION Navy
# LOCATION Western Pacific
# ORGANIZATION LC6
# ORGANIZATION LC7
# GPE Europe
# GPE Germany
# LOCATION Western
# GPE Soviet Union
# GPE Berlin
# GPE Soviet
# GPE Polish
# GPE German
# ORGANIZATION Potsdam
# GPE Japan
# GPE United States
# GPE Japanese
# ORGANIZATION Hiroshima
# PERSON Nagasaki
# GPE Japanese
# GPE Soviet Union
# GPE Japan
# GPE Manchuria
# GPE Japan
# GPE Asia
# ORGANIZATION LC8
# ORGANIZATION LC9
# ORGANIZATION United Nations
# GPE United States
# GPE Soviet Union
# GPE China
# ORGANIZATION United Kingdom
# ORGANIZATION United Nations
# ORGANIZATION Security Council
# GPE Soviet Union
# GPE United States
# GPE European
# GPE Asia
# PERSON Africa
# GPE Europe
# PERSON Line
# PERSON Footer
# ORGANIZATION Contact
# PERSON Footer
# ORGANIZATION API
# PERSON Footer
# PERSON Footer
# PERSON Shop
# PERSON Footer
# PERSON Blog
# PERSON Footer
# ORGANIZATION GitHub
# ORGANIZATION GitHub
# PERSON Footer
# PERSON Footer
# PERSON Privacy
# PERSON Footer
# PERSON Footer
# PERSON Status
# PERSON Footer
# PERSON Help
# GPE Dismiss
